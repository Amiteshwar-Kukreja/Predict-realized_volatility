# %%
import pandas as pd
import numpy as np
import glob
from sb_utils import save_file

import seaborn as sns
import matplotlib.pyplot as plt

from statsmodels.tsa.stattools import acf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, learning_curve
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
#pip install fastparquet

# %%
#pip install pyarrow

# %% [markdown]
# ## 1.0 Key Functions

# %%
def log_return(list_stock_prices):
    return np.log(list_stock_prices).diff()

def realized_volatility(series_log_return):
    return np.sqrt(np.sum(series_log_return**2))

def realized_volatility_per_time_id(file_path, prediction_column_name):
    df_book_data = pd.read_parquet(file_path)
    df_book_data['wap'] =(df_book_data['bid_price1'] * df_book_data['ask_size1']+df_book_data['ask_price1'] * df_book_data['bid_size1'])  / (
                                      df_book_data['bid_size1']+ df_book_data[
                                  'ask_size1'])
    df_book_data['log_return'] = df_book_data.groupby(['time_id'])['wap'].apply(log_return)
    df_book_data = df_book_data[~df_book_data['log_return'].isnull()]
    df_realized_vol_per_stock =  pd.DataFrame(df_book_data.groupby(['time_id'])['log_return'].agg(realized_volatility)).reset_index()
    df_realized_vol_per_stock = df_realized_vol_per_stock.rename(columns = {'log_return':prediction_column_name})
    stock_id = file_path.split('=')[1]
    df_realized_vol_per_stock['row_id'] = df_realized_vol_per_stock['time_id'].apply(lambda x:f'{stock_id}-{x}')
    return df_realized_vol_per_stock[['row_id',prediction_column_name]]

def past_realized_volatility_per_stock(list_file,prediction_column_name):
    df_past_realized = pd.DataFrame()
    for file in list_file:
        df_past_realized = pd.concat([df_past_realized,
                                     realized_volatility_per_time_id(file,prediction_column_name)])
    return df_past_realized

# %% [markdown]
# **Key features for modelling:**
#
# **Stock-related**
# 1) The stock's realized volatility of past time_id based on book wap1 (variation: wap based on level 1 and 2)
# 2) Trade volumes, no. of orders
# 3) realized volatility of trade prices
# 4) Ratio of up_volumes to down_volumes in trade
#         Upvolumes: volume of the trades that happened at a price higher than wap
#         Downvolumes: volume of the trades that happened at a price lower than wap
# 5) log return of the time_ids ending vs starting wap
# 6) Ratio of highest price to lowest price (trade and wap)
# 7) Ratio of up_value to down_value in trade
#         Upvalue: value of the trades that happened at a price higher than wap
#         Downvalues: value of the trades that happened at a price lower than wap
#
#
# **Market-related**
# 1) Average realized volatility of wap across 112 stocks for the time_id
# 2) volume and orders across the market
# 3) average realized volatility of trade prices
# 4) average volatility of stocks in the same cluster
# 5) ratio of highest to lowest volatility during the time period (based on wap)

# %%
s0_book_tr = pd.read_csv('../WIP_data/booknew/train/stock_0_book_train.csv')
s0_book_tr.head()
# Out:
#    seconds_in_bucket  time_id  bid_price1  ask_price1  bid_price2  ask_price2  \
# 0                  0      5.0    1.001422    1.002301     1.00137    1.002353
# 1                  1      5.0    1.001422    1.002301     1.00137    1.002353
# 2                  2      5.0    1.001422    1.002301     1.00137    1.002353
# 3                  3      5.0    1.001422    1.002301     1.00137    1.002353
# 4                  4      5.0    1.001422    1.002301     1.00137    1.002353
#
#    bid_size1  ask_size1  bid_size2  ask_size2  stock_id
# 0        3.0      226.0        2.0      100.0         0
# 1        3.0      100.0        2.0      100.0         0
# 2        3.0      100.0        2.0      100.0         0
# 3        3.0      100.0        2.0      100.0         0
# 4        3.0      100.0        2.0      100.0         0

# %%
s0_book_tr['wap1'] = (s0_book_tr.bid_price1*s0_book_tr.ask_size1 + s0_book_tr.ask_price1*s0_book_tr.bid_size1) \
                        /(s0_book_tr.ask_size1 + s0_book_tr.bid_size1)
                                
s0_book_tr.head()
# Out:
#    seconds_in_bucket  time_id  bid_price1  ask_price1  bid_price2  ask_price2  \
# 0                  0      5.0    1.001422    1.002301     1.00137    1.002353
# 1                  1      5.0    1.001422    1.002301     1.00137    1.002353
# 2                  2      5.0    1.001422    1.002301     1.00137    1.002353
# 3                  3      5.0    1.001422    1.002301     1.00137    1.002353
# 4                  4      5.0    1.001422    1.002301     1.00137    1.002353
#
#    bid_size1  ask_size1  bid_size2  ask_size2  stock_id      wap1
# 0        3.0      226.0        2.0      100.0         0  1.001434
# 1        3.0      100.0        2.0      100.0         0  1.001448
# 2        3.0      100.0        2.0      100.0         0  1.001448
# 3        3.0      100.0        2.0      100.0         0  1.001448
# 4        3.0      100.0        2.0      100.0         0  1.001448

# %%
s0_book_tr['segment_id'] = s0_book_tr['seconds_in_bucket'] // 20

s0_book_tr.head()
# Out:
#    seconds_in_bucket  time_id  bid_price1  ask_price1  bid_price2  ask_price2  \
# 0                  0      5.0    1.001422    1.002301     1.00137    1.002353
# 1                  1      5.0    1.001422    1.002301     1.00137    1.002353
# 2                  2      5.0    1.001422    1.002301     1.00137    1.002353
# 3                  3      5.0    1.001422    1.002301     1.00137    1.002353
# 4                  4      5.0    1.001422    1.002301     1.00137    1.002353
#
#    bid_size1  ask_size1  bid_size2  ask_size2  stock_id      wap1  segment_id
# 0        3.0      226.0        2.0      100.0         0  1.001434           0
# 1        3.0      100.0        2.0      100.0         0  1.001448           0
# 2        3.0      100.0        2.0      100.0         0  1.001448           0
# 3        3.0      100.0        2.0      100.0         0  1.001448           0
# 4        3.0      100.0        2.0      100.0         0  1.001448           0

# %%
s0_book_tr['log_return_segment'] = s0_book_tr.groupby(['time_id', 'segment_id'])['wap1'].apply(log_return)

# %%
s0_book_tr['log_return_time_id'] = s0_book_tr.groupby(['time_id'])['wap1'].apply(log_return)

# %%
s0_book_tr.head()
# Out:
#    seconds_in_bucket  time_id  bid_price1  ask_price1  bid_price2  ask_price2  \
# 0                  0      5.0    1.001422    1.002301     1.00137    1.002353
# 1                  1      5.0    1.001422    1.002301     1.00137    1.002353
# 2                  2      5.0    1.001422    1.002301     1.00137    1.002353
# 3                  3      5.0    1.001422    1.002301     1.00137    1.002353
# 4                  4      5.0    1.001422    1.002301     1.00137    1.002353
#
#    bid_size1  ask_size1  bid_size2  ask_size2  stock_id      wap1  segment_id  \
# 0        3.0      226.0        2.0      100.0         0  1.001434           0
# 1        3.0      100.0        2.0      100.0         0  1.001448           0
# 2        3.0      100.0        2.0      100.0         0  1.001448           0
# 3        3.0      100.0        2.0      100.0         0  1.001448           0
# 4        3.0      100.0        2.0      100.0         0  1.001448           0
#
#    log_return_segment  log_return_time_id
# 0                 NaN                 NaN
# 1            0.000014            0.000014
# 2            0.000000            0.000000
# 3            0.000000            0.000000
# 4            0.000000            0.000000

# %%
s0_book_tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1838400 entries, 0 to 1838399
# Data columns (total 15 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   seconds_in_bucket   int64
#  1   time_id             float64
#  2   bid_price1          float64
#  3   ask_price1          float64
#  4   bid_price2          float64
#  5   ask_price2          float64
#  6   bid_size1           float64
#  7   ask_size1           float64
#  8   bid_size2           float64
#  9   ask_size2           float64
#  10  stock_id            int64
#  11  wap1                float64
#  12  segment_id          int64
#  13  log_return_segment  float64
#  14  log_return_time_id  float64
# dtypes: float64(12), int64(3)
# memory usage: 210.4 MB

# %%
s0_book_tr_segment = s0_book_tr[['seconds_in_bucket', 'time_id','stock_id', 'wap1', 'segment_id', 'log_return_segment']]
s0_book_tr_segment = s0_book_tr_segment[~s0_book_tr_segment['log_return_segment'].isnull()]

s0_realized_vol_by_segment =  pd.DataFrame(s0_book_tr_segment.groupby(['time_id', 'segment_id'])['log_return_segment'].agg(realized_volatility)).reset_index()
s0_realized_vol_by_segment = s0_realized_vol_by_segment.rename(columns = {'log_return_segment': "realized_vol"})

# %%
s0_realized_vol_by_segment.head()
# Out:
#    time_id  segment_id  realized_vol
# 0      5.0           0      0.000018
# 1      5.0           1      0.001057
# 2      5.0           2      0.001266
# 3      5.0           3      0.001090
# 4      5.0           4      0.000052

# %%
import random

plt.style.use('seaborn')

full_list_time_ids = list(s0_realized_vol_by_segment['time_id'].unique())
sub_list_time_ids = random.sample(full_list_time_ids, 12)
sub_array= s0_realized_vol_by_segment[s0_realized_vol_by_segment['time_id'].isin(sub_list_time_ids)]
sns.relplot(x='segment_id', y='realized_vol', data = sub_array,
           kind='line', col='time_id', col_wrap=3)
plt.show()

# %%
import random

plt.style.use('seaborn')

fig, axes = plt.subplots(6,3, figsize = (15,20))

full_list_time_ids = list(s0_realized_vol_by_segment['time_id'].unique())
sub_list_time_ids = list(random.sample(full_list_time_ids, 6))

for i, time_id in enumerate(sub_list_time_ids):
    sub_array= s0_realized_vol_by_segment[s0_realized_vol_by_segment['time_id'] == time_id]
    
    ax = axes.flatten()[i*3]
    ax.plot(sub_array.segment_id, sub_array.realized_vol)
    ax.set_title('Volatility, time_id =' +str(time_id))
    
    ax1 = axes.flatten()[i*3+1]
    plot_acf(sub_array.realized_vol, alpha=0.05, lags = 10, ax = ax1)
    ax1.set_title("ACF: Volatility")
    
    ax2 = axes.flatten()[i*3+2]
    plot_pacf(sub_array.realized_vol, alpha=0.05, lags = 10, ax = ax2)
    ax2.set_title("PACF: Volatility")
    
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

for i, time_id in enumerate(sub_list_time_ids):
    sub_array= s0_realized_vol_by_segment[s0_realized_vol_by_segment['time_id'] == time_id]
    results = adfuller(sub_array.realized_vol)
    print(f'time id: {time_id}, the p-value of the Aug. Dickey Fuller test on Volatility is: {results[1]:4.4f}')
# Out:
# time id: 11007.0, the p-value of the Aug. Dickey Fuller test on Volatility is: 0.0002
# time id: 14476.0, the p-value of the Aug. Dickey Fuller test on Volatility is: 0.0000
# time id: 14797.0, the p-value of the Aug. Dickey Fuller test on Volatility is: 0.0039
# time id: 2892.0, the p-value of the Aug. Dickey Fuller test on Volatility is: 0.0000
# time id: 3069.0, the p-value of the Aug. Dickey Fuller test on Volatility is: 0.0000
# time id: 5218.0, the p-value of the Aug. Dickey Fuller test on Volatility is: 0.0000

# %% [markdown]
# ### Stock_id = 50

# %% [markdown]
# ### Stock_id = 100

# %% [markdown]
# ## 2.0 A peak into the trade data training file
#
# There is a trade_train file available for each of the 112 different stocks. We shall look at this file for a few stocks to understand the data and perform any cleaning, imputing and tidying operations if required.
#
# ### Stock_id=0

# %%
s0_trade_tr = pd.read_csv('../WIP_data/trade/train/stock_0_trade_train.csv')
s0_trade_tr.head()
# Out:
#    time_id  seconds_in_bucket     price  size  order_count  stock_id
# 0        5                 21  1.002301   326           12         0
# 1        5                 46  1.002778   128            4         0
# 2        5                 50  1.002819    55            1         0
# 3        5                 57  1.003155   121            5         0
# 4        5                 68  1.003646     4            1         0

# %%
s0_trade_tr['segment_id'] = s0_trade_tr['seconds_in_bucket'] // 20

s0_trade_tr['time_stamp'] = (s0_trade_tr['time_id'].astype(int)).astype(str) + "-" + s0_trade_tr['segment_id'].astype(str) \
                            + "-" + (s0_trade_tr['seconds_in_bucket'] % 20).astype(str)

# %%
s0_trade_tr.head(10)
# Out:
#    time_id  seconds_in_bucket     price  size  order_count  stock_id  \
# 0        5                 21  1.002301   326           12         0
# 1        5                 46  1.002778   128            4         0
# 2        5                 50  1.002819    55            1         0
# 3        5                 57  1.003155   121            5         0
# 4        5                 68  1.003646     4            1         0
# 5        5                 78  1.003762   134            5         0
# 6        5                122  1.004207   102            3         0
# 7        5                127  1.004577     1            1         0
# 8        5                144  1.004370     6            1         0
# 9        5                147  1.003964   233            4         0
#
#    segment_id time_stamp
# 0           1      5-1-1
# 1           2      5-2-6
# 2           2     5-2-10
# 3           2     5-2-17
# 4           3      5-3-8
# 5           3     5-3-18
# 6           6      5-6-2
# 7           6      5-6-7
# 8           7      5-7-4
# 9           7      5-7-7

# %%
s0_trade_tr['premium'] = np.abs(s0_trade_tr['price_change'])*s0_trade_tr['size']
s0_trade_tr.head(10)
# Out:
#     time_id  seconds_in_bucket     price  size  order_count  stock_id  \
# 1         5                 46  1.002778   128            4         0
# 2         5                 50  1.002819    55            1         0
# 3         5                 57  1.003155   121            5         0
# 4         5                 68  1.003646     4            1         0
# 5         5                 78  1.003762   134            5         0
# 6         5                122  1.004207   102            3         0
# 7         5                127  1.004577     1            1         0
# 8         5                144  1.004370     6            1         0
# 9         5                147  1.003964   233            4         0
# 10        5                177  1.003853     1            1         0
#
#     segment_id time_stamp  price_change  log_return    turnover   premium
# 1            2      5-2-6      0.000477    0.000475  128.355584  0.061018
# 2            2     5-2-10      0.000041    0.000040   55.155017  0.002228
# 3            2     5-2-17      0.000337    0.000336  121.381803  0.040765
# 4            3      5-3-8      0.000490    0.000489    4.014584  0.001962
# 5            3     5-3-18      0.000117    0.000116  134.504175  0.015624
# 6            6      5-6-2      0.000444    0.000442  102.429083  0.045308
# 7            6      5-6-7      0.000370    0.000368    1.004577  0.000370
# 8            7      5-7-4     -0.000207   -0.000206    6.026220  0.001241
# 9            7      5-7-7     -0.000406   -0.000405  233.923519  0.094691
# 10           8     5-8-17     -0.000111   -0.000110    1.003853  0.000111

# %%
s0_trade_tr['price_change'] = s0_trade_tr.groupby(['time_id'])['price'].diff()
s0_trade_tr['log_return'] = s0_trade_tr.groupby(['time_id'])['price'].apply(log_return)
s0_trade_tr['turnover'] = s0_trade_tr['price']*s0_trade_tr['size']
s0_trade_tr['premium'] = s0_trade_tr['price_change']*s0_trade_tr['size']

# %%
s0_trade_tr.head(10)
# Out:
#    time_id  seconds_in_bucket     price  size  order_count  stock_id  \
# 0        5                 21  1.002301   326           12         0
# 1        5                 46  1.002778   128            4         0
# 2        5                 50  1.002819    55            1         0
# 3        5                 57  1.003155   121            5         0
# 4        5                 68  1.003646     4            1         0
# 5        5                 78  1.003762   134            5         0
# 6        5                122  1.004207   102            3         0
# 7        5                127  1.004577     1            1         0
# 8        5                144  1.004370     6            1         0
# 9        5                147  1.003964   233            4         0
#
#    segment_id time_stamp  price_change  log_return    turnover   premium
# 0           1      5-1-1           NaN         NaN  326.750224       NaN
# 1           2      5-2-6      0.000477    0.000475  128.355584  0.061018
# 2           2     5-2-10      0.000041    0.000040   55.155017  0.002228
# 3           2     5-2-17      0.000337    0.000336  121.381803  0.040765
# 4           3      5-3-8      0.000490    0.000489    4.014584  0.001962
# 5           3     5-3-18      0.000117    0.000116  134.504175  0.015624
# 6           6      5-6-2      0.000444    0.000442  102.429083  0.045308
# 7           6      5-6-7      0.000370    0.000368    1.004577  0.000370
# 8           7      5-7-4     -0.000207   -0.000206    6.026220 -0.001241
# 9           7      5-7-7     -0.000406   -0.000405  233.923519 -0.094691

# %%
s0_trade_tr = s0_trade_tr.dropna(how='any')

# %%
s0_trade_tr.head()
# Out:
#    time_id  seconds_in_bucket     price  size  order_count  stock_id  \
# 1        5                 46  1.002778   128            4         0
# 2        5                 50  1.002819    55            1         0
# 3        5                 57  1.003155   121            5         0
# 4        5                 68  1.003646     4            1         0
# 5        5                 78  1.003762   134            5         0
#
#    segment_id time_stamp  price_change  log_return    turnover   premium
# 1           2      5-2-6      0.000477    0.000475  128.355584  0.061018
# 2           2     5-2-10      0.000041    0.000040   55.155017  0.002228
# 3           2     5-2-17      0.000337    0.000336  121.381803  0.040765
# 4           3      5-3-8      0.000490    0.000489    4.014584  0.001962
# 5           3     5-3-18      0.000117    0.000116  134.504175  0.015624

# %%
s0_book_tr.head()
# Out:
#    seconds_in_bucket  time_id  bid_price1  ask_price1  bid_price2  ask_price2  \
# 0                  0      5.0    1.001422    1.002301     1.00137    1.002353
# 1                  1      5.0    1.001422    1.002301     1.00137    1.002353
# 2                  2      5.0    1.001422    1.002301     1.00137    1.002353
# 3                  3      5.0    1.001422    1.002301     1.00137    1.002353
# 4                  4      5.0    1.001422    1.002301     1.00137    1.002353
#
#    bid_size1  ask_size1  bid_size2  ask_size2  stock_id      wap1  segment_id  \
# 0        3.0      226.0        2.0      100.0         0  1.001434           0
# 1        3.0      100.0        2.0      100.0         0  1.001448           0
# 2        3.0      100.0        2.0      100.0         0  1.001448           0
# 3        3.0      100.0        2.0      100.0         0  1.001448           0
# 4        3.0      100.0        2.0      100.0         0  1.001448           0
#
#    log_return_segment  log_return_time_id
# 0                 NaN                 NaN
# 1            0.000014            0.000014
# 2            0.000000            0.000000
# 3            0.000000            0.000000
# 4            0.000000            0.000000

# %%
s0_book_tr_timeid = s0_book_tr[['seconds_in_bucket', 'time_id','stock_id', 'segment_id', 'log_return_time_id']]
s0_book_tr_timeid = s0_book_tr_timeid[~s0_book_tr_timeid['log_return_time_id'].isnull()]

s0_features_and_target =  pd.DataFrame(s0_book_tr_timeid.groupby(['time_id'])['log_return_time_id'].agg(realized_volatility)).reset_index()
s0_features_and_target = s0_features_and_target.rename(columns = {'log_return_time_id': "realized_vol_book"})

# %%
s0_features_and_target.head()
# Out:
#    time_id  realized_vol_book
# 0      5.0           0.004499
# 1     11.0           0.001204
# 2     16.0           0.002369
# 3     31.0           0.002574
# 4     62.0           0.001895

# %%
def high_low_index(price_series):
    return ((np.max(price_series) / np.min(price_series)) * 100.0)

def close_open_index(price_series):
    return ((price_series.values[-1] / price_series.values[0]) * 100.0)

# %%
s0_price_moves = pd.DataFrame(s0_book_tr.groupby(['time_id'])['wap1'].agg([high_low_index, close_open_index])).reset_index()
s0_price_moves.head()
# Out:
#    time_id  high_low_index  close_open_index
# 0      5.0      100.348083        100.229432
# 1     11.0      100.113488        100.036032
# 2     16.0      100.366457         99.792793
# 3     31.0      100.297205         99.717575
# 4     62.0      100.092842         99.999815

# %%
s0_features_and_target.head()
# Out:
#    time_id  realized_vol_book     turnover  size  order_count   premium  \
# 0      5.0           0.004499  2863.388975  2853           98  0.193265
# 1     11.0           0.001204  1287.353777  1287           55  0.057979
# 2     16.0           0.002369  2156.608520  2159           67 -0.498033
# 3     31.0           0.002574  1946.602532  1949           58 -0.149537
# 4     62.0           0.001895  1789.254487  1790           88 -0.105299
#
#    order_value  realized_vol_trade  stock_id    target
# 0    29.218255            0.002006         0  0.004136
# 1    23.406432            0.000901         0  0.001445
# 2    32.188187            0.001961         0  0.002168
# 3    33.562113            0.001561         0  0.002195
# 4    20.332437            0.000871         0  0.001747

# %%
s0_features_and_target = s0_features_and_target.merge(s0_price_moves, on='time_id', how='left')
s0_features_and_target.head()
# Out:
#    time_id  realized_vol_book     turnover  size  order_count   premium  \
# 0      5.0           0.004499  2863.388975  2853           98  0.193265
# 1     11.0           0.001204  1287.353777  1287           55  0.057979
# 2     16.0           0.002369  2156.608520  2159           67 -0.498033
# 3     31.0           0.002574  1946.602532  1949           58 -0.149537
# 4     62.0           0.001895  1789.254487  1790           88 -0.105299
#
#    order_value  realized_vol_trade  stock_id    target  high_low_index  \
# 0    29.218255            0.002006         0  0.004136      100.348083
# 1    23.406432            0.000901         0  0.001445      100.113488
# 2    32.188187            0.001961         0  0.002168      100.366457
# 3    33.562113            0.001561         0  0.002195      100.297205
# 4    20.332437            0.000871         0  0.001747      100.092842
#
#    close_open_index
# 0        100.229432
# 1        100.036032
# 2         99.792793
# 3         99.717575
# 4         99.999815

# %%
trade_features = pd.DataFrame(s0_trade_tr.groupby(['time_id'])['turnover','size','order_count','premium'].sum()).reset_index()
trade_features['order_value'] = trade_features['turnover'] / trade_features['order_count']
trade_features.head()
# Out:
# C:\Users\amite\AppData\Local\Temp/ipykernel_7252/345305771.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   trade_features = pd.DataFrame(s0_trade_tr.groupby(['time_id'])['turnover','size','order_count','premium'].sum()).reset_index()
#    time_id     turnover  size  order_count   premium  order_value
# 0        5  2863.388975  2853           98  0.193265    29.218255
# 1       11  1287.353777  1287           55  0.057979    23.406432
# 2       16  2156.608520  2159           67 -0.498033    32.188187
# 3       31  1946.602532  1949           58 -0.149537    33.562113
# 4       62  1789.254487  1790           88 -0.105299    20.332437

# %%
#older version
#trade_features.head()
# Out:
#    time_id     turnover  size  order_count   premium  order_value
# 0        5  2863.388975  2853           98  0.193265    29.218255
# 1       11  1287.353777  1287           55  0.057979    23.406432
# 2       16  2156.608520  2159           67 -0.498033    32.188187
# 3       31  1946.602532  1949           58 -0.149537    33.562113
# 4       62  1789.254487  1790           88 -0.105299    20.332437

# %%
trade_vol = pd.DataFrame(s0_trade_tr.groupby(['time_id'])['log_return'].agg(realized_volatility)).reset_index()
trade_vol = trade_vol.rename(columns = {'log_return': "realized_vol_trade"})

# %%
trade_vol.head()
# Out:
#    time_id  realized_vol_trade
# 0        5            0.002006
# 1       11            0.000901
# 2       16            0.001961
# 3       31            0.001561
# 4       62            0.000871

# %%
trade_features = trade_features.merge(trade_vol, on='time_id', how='left')
trade_features.head()
# Out:
#    time_id     turnover  size  order_count   premium  order_value  \
# 0        5  2863.388975  2853           98  0.193265    29.218255
# 1       11  1287.353777  1287           55  0.057979    23.406432
# 2       16  2156.608520  2159           67 -0.498033    32.188187
# 3       31  1946.602532  1949           58 -0.149537    33.562113
# 4       62  1789.254487  1790           88 -0.105299    20.332437
#
#    realized_vol_trade
# 0            0.002006
# 1            0.000901
# 2            0.001961
# 3            0.001561
# 4            0.000871

# %%
s0_features_and_target = s0_features_and_target.merge(trade_features, on='time_id', how='left')
s0_features_and_target.head()
# Out:
#    time_id  realized_vol_book     turnover  size  order_count   premium  \
# 0      5.0           0.004499  2863.388975  2853           98  0.193265
# 1     11.0           0.001204  1287.353777  1287           55  0.057979
# 2     16.0           0.002369  2156.608520  2159           67 -0.498033
# 3     31.0           0.002574  1946.602532  1949           58 -0.149537
# 4     62.0           0.001895  1789.254487  1790           88 -0.105299
#
#    order_value  realized_vol_trade
# 0    29.218255            0.002006
# 1    23.406432            0.000901
# 2    32.188187            0.001961
# 3    33.562113            0.001561
# 4    20.332437            0.000871

# %%
target = pd.read_csv('../WIP_data/target_training_data.csv')
target.head()
# Out:
#    stock_id  time_id    target
# 0         0        5  0.004136
# 1         0       11  0.001445
# 2         0       16  0.002168
# 3         0       31  0.002195
# 4         0       62  0.001747

# %%
target_stk_0 = target[target['stock_id'] == 0]
target_stk_0.head()
# Out:
#    stock_id  time_id    target
# 0         0        5  0.004136
# 1         0       11  0.001445
# 2         0       16  0.002168
# 3         0       31  0.002195
# 4         0       62  0.001747

# %%
target.shape, target_stk_0.shape, s0_features_and_target.shape
# Out:
# ((343143, 3), (3064, 3), (3064, 8))

# %%
s0_features_and_target = s0_features_and_target.merge(target_stk_0, on='time_id', how='left')
s0_features_and_target.head()
# Out:
#    time_id  realized_vol_book     turnover  size  order_count   premium  \
# 0      5.0           0.004499  2863.388975  2853           98  0.193265
# 1     11.0           0.001204  1287.353777  1287           55  0.057979
# 2     16.0           0.002369  2156.608520  2159           67 -0.498033
# 3     31.0           0.002574  1946.602532  1949           58 -0.149537
# 4     62.0           0.001895  1789.254487  1790           88 -0.105299
#
#    order_value  realized_vol_trade  stock_id    target
# 0    29.218255            0.002006         0  0.004136
# 1    23.406432            0.000901         0  0.001445
# 2    32.188187            0.001961         0  0.002168
# 3    33.562113            0.001561         0  0.002195
# 4    20.332437            0.000871         0  0.001747

# %%
temp = s0_features_and_target[['realized_vol_book', 'premium', 'target']]
temp['diff'] = s0_features_and_target['realized_vol_book'] - s0_features_and_target['target']
temp.head()
# Out:
# C:\Users\amite\AppData\Local\Temp/ipykernel_7252/1440066820.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['diff'] = s0_features_and_target['realized_vol_book'] - s0_features_and_target['target']
#    realized_vol_book   premium    target      diff
# 0           0.004499  0.193265  0.004136  0.000364
# 1           0.001204  0.057979  0.001445 -0.000240
# 2           0.002369 -0.498033  0.002168  0.000200
# 3           0.002574 -0.149537  0.002195  0.000379
# 4           0.001895 -0.105299  0.001747  0.000147

# %%
features = [feature for feature in temp.columns \
            if feature not in ['target', 'realized_vol_book', 'diff' ]]
scatterplots(temp, features, 'diff', ncol=3, figsize=(12, 6))

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax=sns.heatmap(s0_features_and_target.drop(['time_id', 'stock_id'], axis=1).corr(), annot=True)
ax.xaxis.tick_top()
plt.xticks(fontsize="14", rotation=60)
plt.yticks(fontsize="14", rotation=0)
plt.suptitle("Co-relation between Features and Target", fontsize=16)
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax=sns.heatmap(s0_features_and_target.drop(['time_id', 'stock_id'], axis=1).corr(), annot=True)
ax.xaxis.tick_top()
plt.xticks(fontsize="14", rotation=60)
plt.yticks(fontsize="14", rotation=0)
plt.suptitle("Co-relation between Features and Target", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### stock_id = 50

# %%
# define useful function to create scatterplots of target against desired feature columns

def scatterplots(df, columns, target_col, ncol=None, figsize=(15, 8)):
    if ncol is None:
        ncol = len(columns)
    nrow = int(np.ceil(len(columns) / ncol))
    fig, axes = plt.subplots(nrow, ncol, figsize=figsize, squeeze=False)
    fig.subplots_adjust(wspace=0.5, hspace=0.6)
    for i, col in enumerate(columns):
        ax = axes.flatten()[i]
        ax.scatter(x = col, y = target_col, data=df, alpha=0.5)
        ax.set(xlabel=col, ylabel=target_col)
    nsubplots = nrow * ncol    
    for empty in range(i+1, nsubplots):
        axes.flatten()[empty].set_visible(False)

# %%
features = [feature for feature in s0_features_and_target.columns \
            if feature not in ['time_id', 'stock_id', 'target']]
scatterplots(s0_features_and_target, features, 'target', ncol=3, figsize=(15, 12))

# %%
scatterplots(s0_features_and_target, features, 'target', ncol=3, figsize=(15, 12))

# %%
s0_features_and_target['difference'] = s0_features_and_target['target'] - s0_features_and_target['realized_vol_book']
s0_features_and_target.head()
# Out:
#    time_id  realized_vol_book     turnover  size  order_count   premium  \
# 0      5.0           0.004499  2863.388975  2853           98  0.193265
# 1     11.0           0.001204  1287.353777  1287           55  0.057979
# 2     16.0           0.002369  2156.608520  2159           67 -0.498033
# 3     31.0           0.002574  1946.602532  1949           58 -0.149537
# 4     62.0           0.001895  1789.254487  1790           88 -0.105299
#
#    order_value  realized_vol_trade  stock_id    target  high_low_index  \
# 0    29.218255            0.002006         0  0.004136      100.348083
# 1    23.406432            0.000901         0  0.001445      100.113488
# 2    32.188187            0.001961         0  0.002168      100.366457
# 3    33.562113            0.001561         0  0.002195      100.297205
# 4    20.332437            0.000871         0  0.001747      100.092842
#
#    close_open_index  difference
# 0        100.229432   -0.000364
# 1        100.036032    0.000240
# 2         99.792793   -0.000200
# 3         99.717575   -0.000379
# 4         99.999815   -0.000147

# %%
features = [feature for feature in s0_features_and_target.columns \
            if feature not in ['time_id', 'stock_id', 'target']]
scatterplots(s0_features_and_target, features, 'difference', ncol=3, figsize=(15, 12))

# %%
X = s0_features_and_target.drop(['time_id', 'stock_id', 'target'], axis=1).to_numpy()
y = s0_features_and_target['target'].to_numpy()

scale = StandardScaler()
X_scaled = scale.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.2, random_state = 123)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((2451, 7), (613, 7), (2451,), (613,))

# %%
lr = LinearRegression()
lr_model = lr.fit(X_train, y_train)
y_preds = lr_model.predict(X_test)

R2 = round(r2_score(y_test, y_preds),3)
RMSPE = round(rmspe(y_test, y_preds),3)

print(f'Performance of Linear Regression Model: R2 score: {R2}, RMSPE: {RMSPE}')
# Out:
# Performance of Linear Regression Model: R2 score: 0.642, RMSPE: 0.325

# %%
lr = LinearRegression()
lr_model = lr.fit(X_train, y_train)
y_preds = lr_model.predict(X_test)

R2 = round(r2_score(y_test, y_preds),3)
RMSPE = round(rmspe(y_test, y_preds),3)

print(f'Performance of Linear Regression Model: R2 score: {R2}, RMSPE: {RMSPE}')
# Out:
# Performance of Linear Regression Model: R2 score: 0.641, RMSPE: 0.327

# %% [markdown]
# ### Stock_id=100

# %% [markdown]
# ### 3.0 Train.csv and test.csv files
#
# This file contains the target for each time_id. The **target** is the realized volatility in the 10-min time window following the time_id in question, so it is the value that needs to be predicted based on book and trade data available for a particular time_id.

# %%
train_file = pd.read_csv('../Raw_data/train.csv')
train_file.head(10)
# Out:
#    stock_id  time_id    target
# 0         0        5  0.004136
# 1         0       11  0.001445
# 2         0       16  0.002168
# 3         0       31  0.002195
# 4         0       62  0.001747
# 5         0       72  0.004912
# 6         0       97  0.009388
# 7         0      103  0.004120
# 8         0      109  0.002182
# 9         0      123  0.002669

# %%
realized_vol = realized_volatility(booktrain_trial['logreturn'])
realized_vol
# Out:
# 0.0038217259183637893

# %%
list_order_book_file_train = glob.glob('../Raw_data/book_train.parquet/stock_id=*')


for 
df_past_realized_train = past_realized_volatility_per_stock(list_file=list_order_book_file_train,
                                                           prediction_column_name='pred')

train_file = train_file[train_file['stock_id'] == 0]
train_file['row_id'] = train_file['stock_id'].astype(str) + '-' + train_file['time_id'].astype(str)
train_file = train_file[['row_id','target']]
df_joined = train_file.merge(df_past_realized_train[['row_id','pred']], on = ['row_id'], how = 'left')
df_joined.head()

# %%
fig, ax = plt.subplots(1,1,figsize=(10,5))
ax.boxplot(df_past_realized_train["pred"])
plt.show()

# %%
train_file = pd.read_csv('../Raw_data/train.csv')
test_file = pd.read_csv('../Raw_data/test.csv')
train_file.head(10)
# Out:
#    stock_id  time_id    target
# 0         0        5  0.004136
# 1         0       11  0.001445
# 2         0       16  0.002168
# 3         0       31  0.002195
# 4         0       62  0.001747
# 5         0       72  0.004912
# 6         0       97  0.009388
# 7         0      103  0.004120
# 8         0      109  0.002182
# 9         0      123  0.002669

# %%
plt.style.use('bmh')
g = sns.relplot(x= 'pred', y = 'target', data = df_joined, kind='scatter')
g.fig.set_size_inches(15,15)
plt.xlim(0.0, 0.01)
plt.ylim(0.0, 0.01)
plt.gca().set_aspect('equal', adjustable='box')
plt.plot([0,0.01], [0,0.01], linestyle = "--", color="blue")
plt.show()

# %%
1/1.1
# Out:
# 0.9090909090909091

# %%
np.log(1.1), np.log(0.9090909)
# Out:
# (0.09531017980432493, -0.09531018980432487)

# %%
np.sqrt((np.log(1.1)**2 + np.log(0.9090909)**2))
# Out:
# 0.13478895598256255

# %%
np.sqrt((0.0953**2)*2)
# Out:
# 0.13477455249415596

# %%
def rmspe(y_true, y_pred):
    return  (np.sqrt(np.mean(np.square((y_true - y_pred) / y_true))))

R2 = round(r2_score(y_true = df_joined['target'], y_pred = df_joined['pred']),3)
RMSPE = round(rmspe(y_true = df_joined['target'], y_pred = df_joined['pred']),3)

print(f'Performance of the naive prediction: R2 score: {R2}, RMSPE: {RMSPE}')
# Out:
# Performance of the naive prediction: R2 score: 0.477, RMSPE: 0.393

# %%
X = df_joined['pred'].to_numpy().reshape(-1,1)
y = df_joined['target'].to_numpy()

scale = StandardScaler()
X_scaled = scale.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.2, random_state = 123)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3064, 1), (766, 1), (3064,), (766,))

# %%
lr = LinearRegression()
lr_model = lr.fit(X_train, y_train)
y_preds = lr_model.predict(X_test)

R2 = round(r2_score(y_test, y_preds),3)
RMSPE = round(rmspe(y_test, y_preds),3)

print(f'Performance of Linear Regression Model: R2 score: {R2}, RMSPE: {RMSPE}')
# Out:
# Performance of Linear Regression Model: R2 score: 0.697, RMSPE: 0.347

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(df_joined['pred'], df_joined['target'], test_size = 0.2, random_state = 123)
X_train2.shape, X_test2.shape, y_train2.shape, y_test2.shape
# Out:
# ((3064,), (766,), (3064,), (766,))

# %%
R2 = round(r2_score(y_test2, X_test2),3)
RMSPE = round(rmspe(y_test2, X_test2),3)

print(f'Performance of naive model: R2 score: {R2}, RMSPE: {RMSPE}')
# Out:
# Performance of naive model: R2 score: 0.424, RMSPE: 0.389

# %%
volume = pd.DataFrame(trade_train_0.groupby('time_id')[['size', 'order_count']].sum()).reset_index()
volume.head()
# Out:
#    time_id  size  order_count
# 0        5  3179          110
# 1       11  1289           57
# 2       16  2161           68
# 3       31  1962           59
# 4       62  1791           89

# %%
volume.describe()
# Out:
#             time_id          size  order_count
# count   3830.000000   3830.000000  3830.000000
# mean   16038.933681   3212.919843   102.862141
# std     9366.261949   2060.851470    52.711362
# min        5.000000     64.000000     5.000000
# 25%     7856.500000   1854.250000    66.000000
# 50%    15852.500000   2682.000000    91.000000
# 75%    23988.500000   3941.250000   127.000000
# max    32767.000000  20577.000000   498.000000

# %%
book_temp = book_train_0[:10000]
trade_temp = trade_train_0[:10000]

# %%
# Plot the acf function for bid and trade prices

fig, ax = plt.subplots(2,1,figsize=(16,12))

plot_acf(book_temp.bid_price1, alpha=0.05, lags = 100, ax = ax[0])
ax[0].set_ylabel('Auto Correlation')
ax[0].set_xlabel('Lags')
ax[0].set_title('Auto Correlation - Bid_Prices')

plot_acf(trade_temp.price, alpha=0.05, lags = 100, ax = ax[1])
ax[1].set_ylabel('Auto Correlation')
ax[1].set_xlabel('Lags')
ax[1].set_title('Auto Correlation - Trade_Prices')

plt.show()

# %%
# Plot the acf and pacf function for trade prices

plt.style.use('bmh')
fig, ax = plt.subplots(2,1,figsize=(16,12))

plot_acf(trade_temp.price, alpha=0.05, lags = 100, ax = ax[0])
ax[0].set_title("STOCK 0: ACF - Trade Prices")

plot_pacf(trade_temp.price, alpha=0.05, lags = 100, ax = ax[1])
ax[1].set_title("STOCK 0: Partial ACF - Trade Prices")

plt.show()

# %%
# Plot the acf and pacf function for Weighted Avg. Book Prices

plt.style.use('bmh')
fig, ax = plt.subplots(2,1,figsize=(16,12))

plot_acf(book_temp.wap1, alpha=0.05, lags = 100, ax = ax[0])
ax[0].set_title("STOCK 0: ACF - Weighted Avg. Book Prices")

plot_pacf(book_temp.wap1, alpha=0.05, lags = 100, ax = ax[1])
ax[1].set_title("STOCK 0: Partial ACF - Weighted Avg. Book Prices")

plt.show()

# %%
trade_temp['%_returns'] = trade_temp.price.pct_change() * 100.0
trade_temp.head()
# Out:
# C:\Users\amite\AppData\Local\Temp/ipykernel_7252/905397612.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trade_temp['%_returns'] = trade_temp.price.pct_change() * 100.0
#    time_id  seconds_in_bucket     price  size  order_count  %_returns
# 0        5                 21  1.002301   326           12        NaN
# 1        5                 46  1.002778   128            4   0.047565
# 2        5                 50  1.002818    55            1   0.004029
# 3        5                 57  1.003155   121            5   0.033593
# 4        5                 68  1.003646     4            1   0.048900

# %%
trade_temp.describe()
# Out:
#             time_id  seconds_in_bucket         price         size  \
# count  10000.000000       10000.000000  10000.000000  10000.00000
# mean    1280.653000         297.245600      0.999502     96.07690
# std      703.397415         174.253867      0.002849    144.22076
# min        5.000000           0.000000      0.976170      1.00000
# 25%      650.000000         144.000000      0.998303      2.00000
# 50%     1291.000000         298.000000      0.999780     28.00000
# 75%     1890.000000         450.000000      1.000989    121.00000
# max     2447.000000         599.000000      1.014681   2135.00000
#
#         order_count    %_returns
# count  10000.000000  9999.000000
# mean       3.187200    -0.000022
# std        3.338903     0.083523
# min        1.000000    -1.440150
# 25%        1.000000    -0.022915
# 50%        2.000000     0.000000
# 75%        4.000000     0.021112
# max       70.000000     1.374102

# %%
plt.style.use('bmh')
fig, ax = plt.subplots(1,1,figsize=(16,6))

ax.plot(trade_temp[1:].index, trade_temp[1:]['%_returns'])
ax.set_ylabel('Percentage Returns')
ax.set_xlabel('Time')
ax.set_title('Trade Prices: Percentage Returns Chart')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize = (6,8))

ax.boxplot(trade_temp[1:]['%_returns'])
ax.set_title("Distribution - Trade Price Returns")
ax.set_xlabel("Stock 0")
ax.set_ylabel("Percentage Return")

plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize=(16,6))

plot_acf(trade_temp[1:]['%_returns'], alpha=0.05, lags = 100, ax = ax[0])
ax[0].set_title("STOCK 0: ACF - Trade Price Returns")

plot_pacf(trade_temp[1:]['%_returns'], alpha=0.05, lags = 100, ax = ax[1])
ax[1].set_title("STOCK 0: Partial ACF - Trade Price Returns")

plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

results_price = adfuller(trade_temp[1:].price)
print(f'The p-value of the Augmented Dickey Fuller test on Trade prices is: {results_price[1]:4.4f}')
# Out:
# The p-value of the Augmented Dickey Fuller test on Trade prices is: 0.0000

# %%
results_returns = adfuller(trade_temp[1:]['%_returns'])
print(f'The p-value of the Augmented Dickey Fuller test on Trade returns is: {results_returns[1]:4.4f}')
# Out:
# The p-value of the Augmented Dickey Fuller test on Trade returns is: 0.0000

# %% [markdown]
# ### Stock_id=1

# %%
book_train_1 = pd.read_parquet('../Raw_data/book_train.parquet/stock_id=1/31a1c5cd6d8546b383d10373db762236.parquet')
book_train_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1507532 entries, 0 to 1507531
# Data columns (total 10 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   time_id            1507532 non-null  int16
#  1   seconds_in_bucket  1507532 non-null  int16
#  2   bid_price1         1507532 non-null  float32
#  3   ask_price1         1507532 non-null  float32
#  4   bid_price2         1507532 non-null  float32
#  5   ask_price2         1507532 non-null  float32
#  6   bid_size1          1507532 non-null  int32
#  7   ask_size1          1507532 non-null  int32
#  8   bid_size2          1507532 non-null  int32
#  9   ask_size2          1507532 non-null  int32
# dtypes: float32(4), int16(2), int32(4)
# memory usage: 51.8 MB

# %%
book_train_1['wap1'] = (book_train_1.bid_price1*book_train_1.ask_size1 + book_train_1.ask_price1*book_train_1.bid_size1) \
                        /(book_train_1.ask_size1 + book_train_1.bid_size1)
book_train_1.head()
# Out:
#    time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  ask_price2  \
# 0        5                  0    1.000754    1.001542    1.000689    1.001607
# 1        5                  1    1.000754    1.001673    1.000689    1.001739
# 2        5                  2    1.000754    1.001411    1.000623    1.001476
# 3        5                  3    1.000754    1.001542    1.000689    1.001607
# 4        5                  4    1.000754    1.001476    1.000623    1.001542
#
#    bid_size1  ask_size1  bid_size2  ask_size2      wap1
# 0          1         25         25        100  1.000785
# 1         26         60         25        100  1.001032
# 2          1         25         25        125  1.000780
# 3        125         25        126         36  1.001411
# 4        100        100         25         25  1.001115

# %%
trade_train_1 = pd.read_parquet('../Raw_data/trade_train.parquet/stock_id=1/170b39f1f7144bb3b4554aabc336106e.parquet')
trade_train_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296210 entries, 0 to 296209
# Data columns (total 5 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   time_id            296210 non-null  int16
#  1   seconds_in_bucket  296210 non-null  int16
#  2   price              296210 non-null  float32
#  3   size               296210 non-null  int32
#  4   order_count        296210 non-null  int16
# dtypes: float32(1), int16(3), int32(1)
# memory usage: 4.0 MB

# %%
trade_train_1.describe()
# Out:
#             time_id  seconds_in_bucket          price           size  \
# count  296210.00000      296210.000000  296210.000000  296210.000000
# mean    15964.78176         297.849924       1.000025     162.053800
# std      9405.00168         173.628242       0.004899     280.820086
# min         5.00000           0.000000       0.937487       1.000000
# 25%      7743.00000         147.000000       0.998156      15.000000
# 50%     15770.00000         297.000000       0.999951     100.000000
# 75%     23834.00000         448.000000       1.001696     200.000000
# max     32767.00000         599.000000       1.049819   35727.000000
#
#          order_count
# count  296210.000000
# mean        3.113541
# std         3.394705
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max       129.000000

# %%
book_temp = book_train_1[:10000]
trade_temp = trade_train_1[:10000]

# %%
plt.style.use('bmh')
fig, ax = plt.subplots(1,2,figsize=(16,8))

ax[0].plot(book_train_1.index, book_train_1.bid_price1)
ax[0].set_ylabel('Bid Price')
ax[0].set_xlabel('Time')
ax[0].set_title('Bid_Price Chart')

ax[1].plot(trade_train_1.index, trade_train_1.price)
ax[1].set_ylabel('Trade Price')
ax[1].set_xlabel('Time')
ax[1].set_title('Trade_Price Chart')

plt.show()

# %%
trade_temp['returns'] = trade_temp.price.pct_change()
trade_temp.head()
# Out:
# C:\Users\amite\AppData\Local\Temp/ipykernel_7252/2556525513.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trade_temp['returns'] = trade_temp.price.pct_change()
#    time_id  seconds_in_bucket     price  size  order_count   returns
# 0        5                 28  1.002080   553           11       NaN
# 1        5                 39  1.002460     8            3  0.000379
# 2        5                 42  1.002308   147            4 -0.000152
# 3        5                 44  1.002788     1            1  0.000479
# 4        5                 51  1.002657   100            2 -0.000131

# %%
plt.style.use('bmh')
fig, ax = plt.subplots(2,1,figsize=(16,12))

plot_acf(trade_temp.price, alpha=0.05, lags = 100, ax = ax[0])

plot_pacf(trade_temp.price, alpha=0.05, lags = 100, ax = ax[1])

plt.show()

# %%
plt.style.use('bmh')
fig, ax = plt.subplots(2,1,figsize=(16,12))

plot_acf(book_temp.wap1, alpha=0.05, lags = 100, ax = ax[0])

plot_pacf(book_temp.wap1, alpha=0.05, lags = 100, ax = ax[1])

plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize=(16,6))

ax.plot(trade_temp[1:].index, trade_temp[1:].returns)
ax.set_ylabel('Returns')
ax.set_xlabel('Time')
ax.set_title('Trade Returns Chart')
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

results_price = adfuller(trade_temp[1:].price)
print(f'The p-value of the test on prices is: {results_price[1]:4.4f}')

results_returns = adfuller(trade_temp[1:].returns)
print(f'The p-value of the test on returns is: {results_returns[1]:4.4f}')
# Out:
# The p-value of the test on prices is: 0.0000
# The p-value of the test on returns is: 0.0000

# %% [markdown]
# ### Stock_id=100

# %%
book_train_100 = pd.read_parquet('../Raw_data/book_train.parquet/stock_id=100/9495f2c64cee42078601dee7408e3c36.parquet')
book_train_100['wap1'] = (book_train_100.bid_price1*book_train_100.ask_size1 + book_train_100.ask_price1*book_train_100.bid_size1) \
                        /(book_train_100.ask_size1 + book_train_100.bid_size1)
book_train_100.head()
# Out:
#    time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  ask_price2  \
# 0        5                  0    0.999077    1.000103    0.999009    1.000239
# 1        5                  4    0.999214    1.000103    0.999145    1.000239
# 2        5                  5    0.999282    1.000239    0.999214    1.000376
# 3        5                  6    0.999487    1.000786    0.999419    1.000855
# 4        5                  7    0.999624    1.000786    0.999556    1.000855
#
#    bid_size1  ask_size1  bid_size2  ask_size2      wap1
# 0        100          7         64        100  1.000035
# 1        300          7        310        100  1.000082
# 2        700        201        400         36  1.000026
# 3        100        101         10         50  1.000134
# 4        200        101        100         50  1.000396

# %%
trade_train_100 = pd.read_parquet('../Raw_data/trade_train.parquet/stock_id=100/c6b5a2974aac4210a6803c5907baaa07.parquet')

# %%
book_temp = book_train_100[:10000]
trade_temp = trade_train_100[:10000]
trade_temp['%_returns'] = trade_temp.price.pct_change() * 100.0
trade_temp.head()
# Out:
# C:\Users\amite\AppData\Local\Temp/ipykernel_7252/4180292391.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trade_temp['%_returns'] = trade_temp.price.pct_change() * 100.0
#    time_id  seconds_in_bucket     price  size  order_count  %_returns
# 0        5                  5  1.000103     7            2        NaN
# 1        5                  6  1.000239   201            4   0.013685
# 2        5                  9  1.000444     1            1   0.020504
# 3        5                 28  1.000376    12            3  -0.006825
# 4        5                 30  1.000444     3            1   0.006831

# %%
plt.style.use('bmh')
fig, ax = plt.subplots(1,1,figsize=(16,6))

ax.plot(trade_temp[1:].index, trade_temp[1:]['%_returns'])
ax.set_ylabel('Percentage Returns')
ax.set_xlabel('Time')
ax.set_title('Trade Prices: Percentage Returns Chart')
plt.show()

# %%
plt.style.use('bmh')
fig, ax = plt.subplots(2,1,figsize=(16,12))

plot_acf(trade_temp.price, alpha=0.05, lags = 100, ax = ax[0])

plot_pacf(trade_temp.price, alpha=0.05, lags = 100, ax = ax[1])

plt.show()

# %%
plt.style.use('bmh')
fig, ax = plt.subplots(2,1,figsize=(16,12))

plot_acf(book_temp.wap1, alpha=0.05, lags = 100, ax = ax[0])

plot_pacf(book_temp.wap1, alpha=0.05, lags = 100, ax = ax[1])

plt.show()

# %%
x = [100, 101, 102, 105]
y = pd.DataFrame(x, columns = ['Col1'])
y
# Out:
#    Col1
# 0   100
# 1   101
# 2   102
# 3   105

# %%
y['returns'] = y.Col1.pct_change()
y
# Out:
#    Col1   returns
# 0   100       NaN
# 1   101  0.010000
# 2   102  0.009901
# 3   105  0.029412
